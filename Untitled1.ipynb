# %%
# 1. Uninstall the broken vision components and the current torch
#%pip uninstall -y torchvision torch transformers

# 2. Reinstall only the core Torch and Transformers (skipping torchvision for now)
# We use the CPU/Standard version of torch first to verify the logic works
# %pip install torch transformers accelerate --index-url https://download.pytorch.org/whl/cu124

# 3. Clear the cache and restart the kernel
# %pip cache purge

# %%
# 1. Force remove the "ghost" installations
#pip uninstall -y torch torchvision torchaudio transformers accelerate bitsandbytes

# 2. Install the specific Blackwell-optimized stack for ARM64
# In 2026, DGX Spark requires CUDA 13.0+ support
# %pip install torch torchvision torchaudio \
    --index-url https://download.pytorch.org/whl/cu130 \
    --extra-index-url https://pypi.nvidia.com

# 3. Reinstall transformers and its assistants
# %pip install transformers>=4.48.0 accelerate>=1.3.0 bitsandbytes>=0.45.0

# %%
# !pip install transformers -q
# !pip install datasets -q
# !pip install spacy -q
# !pip install wordcloud -q

# %%
# !pip install -U transformers

# %%
import sys
import torch
import torchvision

print(f"Python version: {sys.version}")
print(f"Torch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")

try:
    from transformers import pipeline, AutoProcessor
    print("✅ Success: Pipeline and Processor imported!")
except ImportError as e:
    print(f"❌ Failed: {e}")

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("image-to-text", model="Qwen/Qwen3-VL-235B-A22B-Thinking")

# %%
# Load model directly
from transformers import AutoProcessor, AutoModelForImageTextToText

processor = AutoProcessor.from_pretrained("Qwen/Qwen3-VL-235B-A22B-Thinking")
model = AutoModelForImageTextToText.from_pretrained("Qwen/Qwen3-VL-235B-A22B-Thinking")
